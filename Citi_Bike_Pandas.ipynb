# %%
import pandas as pd
import datetime as dt

# %%
df_feb_2021 = pd.read_csv("Resources/202102-citibike-tripdata.csv", low_memory=False)

# %%
df_feb_2022 = pd.read_csv("Resources/202202-citibike-tripdata.csv", low_memory=False)

# %%
df_feb_2021.dropna()
# Out:
#                  ride_id rideable_type           started_at  \
# 0       BBA33D73DECE976F   docked_bike  2021-02-26 16:38:54
# 1       B63D7AFF9AC5B6D4   docked_bike  2021-02-17 11:09:11
# 2       52B829195C469D99   docked_bike  2021-02-26 18:33:29
# 3       19C84ECA2B468476   docked_bike  2021-02-26 12:48:35
# 4       C0DDB771E70D9DF5   docked_bike  2021-02-25 17:23:22
# ...                  ...           ...                  ...
# 649978  84DA58E73B2DF079   docked_bike  2021-02-12 16:01:17
# 649979  3A14299B4F7FA1CF   docked_bike  2021-02-17 18:03:24
# 649980  7B86EE3DC7E026BC   docked_bike  2021-02-28 18:58:31
# 649981  D665B8623FC01285   docked_bike  2021-02-25 09:00:41
# 649982  08A07BB378B0FE2F   docked_bike  2021-02-08 13:31:57
#
#                    ended_at        start_station_name start_station_id  \
# 0       2021-02-26 16:44:37        E 84 St & Park Ave          7243.04
# 1       2021-02-17 11:26:47   Macon St & Nostrand Ave          4214.03
# ...

# %%
df_feb_2022.dropna()
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        6C29577D0141AACD  electric_bike  2022-02-27 16:00:58
# 1        353462A61AFB32C8   classic_bike  2022-02-02 18:09:30
# 2        220081222C7CC84D   classic_bike  2022-02-10 19:41:09
# 3        C66CB5EDE74A7404   classic_bike  2022-02-14 15:52:02
# 4        6B997C1E4DCDD6BF   classic_bike  2022-02-23 13:25:07
# ...                   ...            ...                  ...
# 1233709  DB7E2CCB36FE2470   classic_bike  2022-02-02 20:20:40
# 1233710  2589BCEF3734CEFA  electric_bike  2022-02-12 18:21:44
# 1233711  D808B985BB9F9D72   classic_bike  2022-02-26 12:58:46
# 1233712  F3CBF555F8561BF0  electric_bike  2022-02-18 11:03:02
# 1233713  2F8F2920C1A9D0E8  electric_bike  2022-02-19 18:11:55
#
#                     ended_at           start_station_name start_station_id  \
# 0        2022-02-27 16:10:09         Cliff St & Fulton St          5065.14
# ...
